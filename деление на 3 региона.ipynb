# %%
import pandas as pd

# %%
df = pd.read_excel('cashback.xlsx')

# %%
msc = df[df['регион_проживания'] == 'Москва']
df = df[df['регион_проживания'] != 'Москва']

counts = df['регион_проживания'].value_counts().sort_values(ascending=[False])
indexes = counts.index

regs1 = pd.DataFrame(index=[], columns={'count': []})
regs2 = pd.DataFrame(index=[], columns={'count': []})

for i in range(len(counts)):
    if regs1['count'].sum() <= regs2['count'].sum():
        regs1.at[indexes[i], 'count'] = counts[i]
    else:
        regs2.at[indexes[i], 'count'] = counts[i]
list(regs1.index)
# Out:
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs2.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# C:\Users\Salir\AppData\Local\Temp\ipykernel_150436\2615962663.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   regs1.at[indexes[i], 'count'] = counts[i]
# ['Санкт-Петербург',
#  'Новосибирская область',
#  'Челябинская область',
#  'Республика Башкортостан',
#  'Пермский край',
#  'Воронежская область',
#  'Хабаровский край',
#  'Калининградская область',
#  'Саратовская область',
#  'Ханты-Мансийский автономный округ',
#  'Ставропольский край',
#  'Ярославская область',
#  'Омская область',
#  'Калужская область',
#  'Амурская область',
#  'Архангельская область',
#  'Ленинградская область',
#  'Тверская область',
#  'Республика Крым',
#  'Курская область',
#  'Республика Бурятия',
#  'Тульская область',
#  'Смоленская область',
#  'Мурманская область',
#  'Астраханская область',
#  'Пензенская область',
#  'Брянская область',
#  'Республика Саха (Якутия)',
#  'Костромская область',
#  'Республика Марий Эл',
#  'Республика Мордовия',
#  'Республика Карелия',
#  'Камчатский край',
#  'Курганская область',
#  'Республика Северная Осетия',
#  'Республика Кабардино-Балкария',
#  'Ненецкий автономный округ',
#  'Республика Карачаево-Черкесия',
#  'Еврейская автономная область']
