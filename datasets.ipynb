# %%
pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("cashback.xlsx")
df_moscow = df[df["город_проживания"] == "Москва"]
df_saint = df[df["город_проживания"] == "Санкт-Петербург"]
df_regions = df.loc[((df["город_проживания"] != "Москва") & (df["город_проживания"] != "Санкт-Петербург"))]
print(df_moscow,df_saint, df_regions)
# Out:
#        ключ_клиента регион_проживания город_проживания  возраст  пол  \
# 0              1889            Москва           Москва       50    M
# 1              1889            Москва           Москва       50    M
# 2              1889            Москва           Москва       50    M
# 3              1889            Москва           Москва       50    M
# 4              1889            Москва           Москва       50    M
# ...             ...               ...              ...      ...  ...
# 59821    1005319581            Москва           Москва       37  NaN
# 59822    1005319581            Москва           Москва       37  NaN
# 59823    1005319581            Москва           Москва       37  NaN
# 59824    1005319581            Москва           Москва       37  NaN
# 59825    1005319581            Москва           Москва       37  NaN
#
#       месяц_покупок  оборот_аптеки  оборот_рестораны  оборот_одежда_и_обувь  \
# ...

# %%
df_moscow_gd = df_moscow[["ключ_клиента", "месяц_покупок", "оборот_жд_билеты", "активация_кэшбэка_жд_билеты"]].fillna(0)
df_moscow_edc = df_moscow[["ключ_клиента", "месяц_покупок", "оборот_образование", "активация_кэшбэка_образование"]].fillna(0)
df_moscow_house = df_moscow[["ключ_клиента", "месяц_покупок", "оборот_дом_и_ремонт", "активация_кэшбэка_дом_и_ремонт"]].fillna(0) 
df_moscow_sport =  df_moscow[["ключ_клиента", "месяц_покупок", "оборот_спорттовары", "активация_кэшбэка_спорттовары"]].fillna(0) 
df_moscow_animals = df_moscow[["ключ_клиента", "месяц_покупок", "оборот_животные", "активация_кэшбэка_животные"]].fillna(0)
df_moscow_flowers = df_moscow[["ключ_клиента", "месяц_покупок", "оборот_цветы", "активация_кэшбэка_цветы"]].fillna(0) 
df_moscow_fastfood = df_moscow[["ключ_клиента", "месяц_покупок", "оборот_фастфуд", "активация_кэшбэка_фастфуд"]].fillna(0) 
df_moscow_carsharing = df_moscow[["ключ_клиента", "месяц_покупок", "оборот_каршеринг", "активация_кэшбэка_каршеринг"]].fillna(0) 
df_moscow_auto = df_moscow[["ключ_клиента", "месяц_покупок", "оборот_аренда_авто", "активация_кэшбэка_аренда_авто"]].fillna(0) 
print(len(df_moscow_gd.groupby("ключ_клиента")))
# Out:
# 4848

# %%
df_saint_gd = df_saint[["ключ_клиента", "месяц_покупок", "оборот_жд_билеты", "активация_кэшбэка_жд_билеты"]].fillna(0) 
df_saint_edc = df_saint[["ключ_клиента", "месяц_покупок", "оборот_образование", "активация_кэшбэка_образование"]].fillna(0)
df_saint_house = df_saint[["ключ_клиента", "месяц_покупок", "оборот_дом_и_ремонт", "активация_кэшбэка_дом_и_ремонт"]].fillna(0) 
df_saint_sport =  df_saint[["ключ_клиента", "месяц_покупок", "оборот_спорттовары", "активация_кэшбэка_спорттовары"]].fillna(0) 
df_saint_animals = df_saint[["ключ_клиента", "месяц_покупок", "оборот_животные", "активация_кэшбэка_животные"]].fillna(0)
df_saint_flowers = df_saint[["ключ_клиента", "месяц_покупок", "оборот_цветы", "активация_кэшбэка_цветы"]].fillna(0) 
df_saint_fastfood = df_saint[["ключ_клиента", "месяц_покупок", "оборот_фастфуд", "активация_кэшбэка_фастфуд"]].fillna(0) 
df_saint_carsharing = df_saint[["ключ_клиента", "месяц_покупок", "оборот_каршеринг", "активация_кэшбэка_каршеринг"]].fillna(0) 
df_saint_auto = df_saint[["ключ_клиента", "месяц_покупок", "оборот_аренда_авто", "активация_кэшбэка_аренда_авто"]].fillna(0)

# %%
df_regions_gd = df_regions[["ключ_клиента", "месяц_покупок", "оборот_жд_билеты", "активация_кэшбэка_жд_билеты"]].fillna(0) 
df_regions_edc = df_regions[["ключ_клиента", "месяц_покупок", "оборот_образование", "активация_кэшбэка_образование"]].fillna(0)
df_regions_house = df_regions[["ключ_клиента", "месяц_покупок", "оборот_дом_и_ремонт", "активация_кэшбэка_дом_и_ремонт"]].fillna(0) 
df_regions_sport =  df_regions[["ключ_клиента", "месяц_покупок", "оборот_спорттовары", "активация_кэшбэка_спорттовары"]].fillna(0) 
df_regions_animals = df_regions[["ключ_клиента", "месяц_покупок", "оборот_животные", "активация_кэшбэка_животные"]].fillna(0)
df_regions_flowers = df_regions[["ключ_клиента", "месяц_покупок", "оборот_цветы", "активация_кэшбэка_цветы"]].fillna(0) 
df_regions_fastfood = df_regions[["ключ_клиента", "месяц_покупок", "оборот_фастфуд", "активация_кэшбэка_фастфуд"]].fillna(0) 
df_regions_carsharing = df_regions[["ключ_клиента", "месяц_покупок", "оборот_каршеринг", "активация_кэшбэка_каршеринг"]].fillna(0) 
df_regions_auto = df_regions[["ключ_клиента", "месяц_покупок", "оборот_аренда_авто", "активация_кэшбэка_аренда_авто"]].fillna(0)

# %%
df_moscow_gd = df_moscow_gd[df_moscow_gd.duplicated(subset=["ключ_клиента"], keep=False)]
df_moscow_edc = df_moscow_edc[df_moscow_edc.duplicated(subset=["ключ_клиента"], keep=False)]
df_moscow_house = df_moscow_house[df_moscow_house.duplicated(subset=["ключ_клиента"], keep=False)]
df_moscow_sport = df_moscow_sport[df_moscow_sport.duplicated(subset=["ключ_клиента"], keep=False)]
df_moscow_animals = df_moscow_animals[df_moscow_animals.duplicated(subset=["ключ_клиента"], keep=False)]
df_moscow_flowers = df_moscow_flowers[df_moscow_flowers.duplicated(subset=["ключ_клиента"], keep=False)]
df_moscow_fastfood = df_moscow_fastfood[df_moscow_fastfood.duplicated(subset=["ключ_клиента"], keep=False)]
df_moscow_carsharing = df_moscow_carsharing[df_moscow_carsharing.duplicated(subset=["ключ_клиента"], keep=False)]
df_moscow_auto= df_moscow_auto[df_moscow_auto.duplicated(subset=["ключ_клиента"], keep=False)]
df_saint_gd = df_saint_gd[df_saint_gd.duplicated(subset=["ключ_клиента"], keep=False)]
df_saint_edc = df_saint_edc[df_saint_edc.duplicated(subset=["ключ_клиента"], keep=False)]
df_saint_house = df_saint_house[df_saint_house.duplicated(subset=["ключ_клиента"], keep=False)]
df_saint_sport = df_saint_sport[df_saint_sport.duplicated(subset=["ключ_клиента"], keep=False)]
df_saint_animals = df_saint_animals[df_saint_animals.duplicated(subset=["ключ_клиента"], keep=False)]
df_saint_flowers = df_saint_flowers[df_saint_flowers.duplicated(subset=["ключ_клиента"], keep=False)]
df_saint_fastfood = df_saint_fastfood[df_saint_fastfood.duplicated(subset=["ключ_клиента"], keep=False)]
df_saint_carsharing = df_saint_carsharing[df_saint_carsharing.duplicated(subset=["ключ_клиента"], keep=False)]
df_saint_auto= df_saint_auto[df_saint_auto.duplicated(subset=["ключ_клиента"], keep=False)]
df_regions_gd = df_regions_gd[df_regions_gd.duplicated(subset=["ключ_клиента"], keep=False)]
df_regions_edc = df_regions_edc[df_regions_edc.duplicated(subset=["ключ_клиента"], keep=False)]
df_regions_house = df_regions_house[df_regions_house.duplicated(subset=["ключ_клиента"], keep=False)]
df_regions_sport = df_regions_sport[df_regions_sport.duplicated(subset=["ключ_клиента"], keep=False)]
df_regions_animals = df_regions_animals[df_regions_animals.duplicated(subset=["ключ_клиента"], keep=False)]
df_regions_flowers = df_regions_flowers[df_regions_flowers.duplicated(subset=["ключ_клиента"], keep=False)]
df_regions_fastfood = df_regions_fastfood[df_regions_fastfood.duplicated(subset=["ключ_клиента"], keep=False)]
df_regions_carsharing = df_regions_carsharing[df_regions_carsharing.duplicated(subset=["ключ_клиента"], keep=False)]
df_regions_auto= df_regions_auto[df_regions_auto.duplicated(subset=["ключ_клиента"], keep=False)]

# %%
df_moscow_gd_grouped = df_moscow_gd.groupby(["ключ_клиента", "активация_кэшбэка_жд_билеты"]).mean("оборот_жд_билеты")
df_moscow_edc_grouped = df_moscow_edc.groupby(["ключ_клиента", "активация_кэшбэка_образование"]).mean("оборот_образование")
df_moscow_house_grouped = df_moscow_house.groupby(["ключ_клиента", "активация_кэшбэка_дом_и_ремонт"]).mean("оборот_дом_и_ремонт")
df_moscow_sport_grouped = df_moscow_sport.groupby(["ключ_клиента", "активация_кэшбэка_спорттовары"]).mean("оборот_спорттовары")
df_moscow_animals_grouped = df_moscow_animals.groupby(["ключ_клиента", "активация_кэшбэка_животные"]).mean("оборот_животные")
df_moscow_flowers_grouped = df_moscow_flowers.groupby(["ключ_клиента", "активация_кэшбэка_цветы"]).mean("оборот_цветы")
df_moscow_fastfood_grouped = df_moscow_fastfood.groupby(["ключ_клиента", "активация_кэшбэка_фастфуд"]).mean("оборот_фастфуд")
df_moscow_carsharing_grouped = df_moscow_carsharing.groupby(["ключ_клиента", "активация_кэшбэка_каршеринг"]).mean("оборот_каршеринг")
df_moscow_auto_grouped = df_moscow_auto.groupby(["ключ_клиента", "активация_кэшбэка_аренда_авто"]).mean("оборот_аренда_авто")
df_moscow_gd_grouped_perc = ((sum(list(df_moscow_gd_grouped.values[i+1] > 1.05 * df_moscow_gd_grouped.values[i] for i in range(0,len(df_moscow_gd_grouped.values)-1,2))) / len(df_moscow_gd_grouped)*200)[0])
df_moscow_edc_grouped_perc = ((sum(list(df_moscow_edc_grouped.values[i+1] > 1.05 * df_moscow_edc_grouped.values[i] for i in range(0,len(df_moscow_edc_grouped.values)-1,2))) / len(df_moscow_edc_grouped)*200)[0])
df_moscow_house_grouped_perc = ((sum(list(df_moscow_house_grouped.values[i+1] > 1.05* df_moscow_house_grouped.values[i] for i in range(0,len(df_moscow_house_grouped.values)-1,2))) / len(df_moscow_house_grouped)*200)[0])
df_moscow_sport_grouped_perc = ((sum(list(df_moscow_sport_grouped.values[i+1] > 1.05 * df_moscow_sport_grouped.values[i] for i in range(0,len(df_moscow_sport_grouped.values)-1,2))) / len(df_moscow_sport_grouped)*200)[0])
df_moscow_animals_grouped_perc = ((sum(list(df_moscow_animals_grouped.values[i+1] >1.05 * df_moscow_animals_grouped.values[i] for i in range(0,len(df_moscow_animals_grouped.values)-1,2))) / len(df_moscow_animals_grouped)*200)[0])
df_moscow_fastfood_grouped_perc = ((sum(list(df_moscow_fastfood_grouped.values[i+1] > 1.05 *df_moscow_fastfood_grouped.values[i] for i in range(0,len(df_moscow_fastfood_grouped.values)-1,2))) / len(df_moscow_fastfood_grouped)*200)[0])
df_moscow_flowers_grouped_perc = ((sum(list(df_moscow_flowers_grouped.values[i+1] > 1.05 *df_moscow_flowers_grouped.values[i] for i in range(0,len(df_moscow_flowers_grouped.values)-1,2))) / len(df_moscow_flowers_grouped)*200)[0])
df_moscow_carsharing_grouped_perc = ((sum(list(df_moscow_carsharing_grouped.values[i+1] >1.05 * df_moscow_carsharing_grouped.values[i] for i in range(0,len(df_moscow_carsharing_grouped.values)-1,2))) / len(df_moscow_carsharing_grouped)*200)[0])
df_moscow_auto_grouped_perc = ((sum(list(df_moscow_auto_grouped.values[i+1] >1.05 * df_moscow_auto_grouped.values[i] for i in range(0,len(df_moscow_auto_grouped.values)-1,2))) / len(df_moscow_auto_grouped)*200)[0])
df_saint_gd_grouped = df_saint_gd.groupby(["ключ_клиента", "активация_кэшбэка_жд_билеты"]).mean("оборот_жд_билеты")
df_saint_edc_grouped = df_saint_edc.groupby(["ключ_клиента", "активация_кэшбэка_образование"]).mean("оборот_образование")
df_saint_flowers_grouped = df_saint_flowers.groupby(["ключ_клиента", "активация_кэшбэка_цветы"]).mean("оборот_цветы")
df_saint_house_grouped = df_saint_house.groupby(["ключ_клиента", "активация_кэшбэка_дом_и_ремонт"]).mean("оборот_дом_и_ремонт")
df_saint_sport_grouped = df_saint_sport.groupby(["ключ_клиента", "активация_кэшбэка_спорттовары"]).mean("оборот_спорттовары")
df_saint_animals_grouped = df_saint_animals.groupby(["ключ_клиента", "активация_кэшбэка_животные"]).mean("оборот_животные")
df_saint_fastfood_grouped = df_saint_fastfood.groupby(["ключ_клиента", "активация_кэшбэка_фастфуд"]).mean("оборот_фастфуд")
df_saint_carsharing_grouped = df_saint_carsharing.groupby(["ключ_клиента", "активация_кэшбэка_каршеринг"]).mean("оборот_каршеринг")
df_saint_auto_grouped = df_saint_auto.groupby(["ключ_клиента", "активация_кэшбэка_аренда_авто"]).mean("оборот_аренда_авто")
df_saint_gd_grouped_perc = ((sum(list(df_saint_gd_grouped.values[i+1] > 1.05 *df_saint_gd_grouped.values[i] for i in range(0,len(df_saint_gd_grouped.values)-1,2))) / len(df_saint_gd_grouped)*200)[0])
df_saint_edc_grouped_perc = ((sum(list(df_saint_edc_grouped.values[i+1] > 1.05 *df_saint_edc_grouped.values[i] for i in range(0,len(df_saint_edc_grouped.values)-1,2))) / len(df_saint_edc_grouped)*200)[0])
df_saint_house_grouped_perc = ((sum(list(df_saint_house_grouped.values[i+1] > 1.05 *df_saint_house_grouped.values[i] for i in range(0,len(df_saint_house_grouped.values)-1,2))) / len(df_saint_house_grouped)*200)[0])
df_saint_sport_grouped_perc = ((sum(list(df_saint_sport_grouped.values[i+1] >1.05 * df_saint_sport_grouped.values[i] for i in range(0,len(df_saint_sport_grouped.values)-1,2))) / len(df_saint_sport_grouped)*200)[0])
df_saint_animals_grouped_perc = ((sum(list(df_saint_animals_grouped.values[i+1] > 1.05 *df_saint_animals_grouped.values[i] for i in range(0,len(df_saint_animals_grouped.values)-1,2))) / len(df_saint_animals_grouped)*200)[0])
df_saint_fastfood_grouped_perc = ((sum(list(df_saint_fastfood_grouped.values[i+1] > 1.05 *df_saint_fastfood_grouped.values[i] for i in range(0,len(df_saint_fastfood_grouped.values)-1,2))) / len(df_saint_fastfood_grouped)*200)[0])
df_saint_flowers_grouped_perc = ((sum(list(df_saint_flowers_grouped.values[i+1] > 1.05 *df_saint_flowers_grouped.values[i] for i in range(0,len(df_saint_flowers_grouped.values)-1,2))) / (len(df_saint_flowers_grouped)*200))[0])
df_saint_carsharing_grouped_perc = ((sum(list(df_saint_carsharing_grouped.values[i+1] > 1.05 *df_saint_carsharing_grouped.values[i] for i in range(0,len(df_saint_carsharing_grouped.values)-1,2))) / len(df_saint_carsharing_grouped)*200)[0])
df_saint_auto_grouped_perc = 0 # нет данных
df_regions_gd_grouped = df_regions_gd.groupby(["ключ_клиента", "активация_кэшбэка_жд_билеты"]).mean("оборот_жд_билеты")
df_regions_flowers_grouped = df_regions_flowers.groupby(["ключ_клиента", "активация_кэшбэка_цветы"]).mean("оборот_цветы")
df_regions_edc_grouped = df_regions_edc.groupby(["ключ_клиента", "активация_кэшбэка_образование"]).mean("оборот_образование")
df_regions_house_grouped = df_regions_house.groupby(["ключ_клиента", "активация_кэшбэка_дом_и_ремонт"]).mean("оборот_дом_и_ремонт")
df_regions_sport_grouped = df_regions_sport.groupby(["ключ_клиента", "активация_кэшбэка_спорттовары"]).mean("оборот_спорттовары")
df_regions_animals_grouped = df_regions_animals.groupby(["ключ_клиента", "активация_кэшбэка_животные"]).mean("оборот_животные")
df_regions_fastfood_grouped = df_regions_fastfood.groupby(["ключ_клиента", "активация_кэшбэка_фастфуд"]).mean("оборот_фастфуд")
df_regions_carsharing_grouped = df_regions_carsharing.groupby(["ключ_клиента", "активация_кэшбэка_каршеринг"]).mean("оборот_каршеринг")
df_regions_auto_grouped = df_regions_auto.groupby(["ключ_клиента", "активация_кэшбэка_аренда_авто"]).mean("оборот_аренда_авто")
df_regions_gd_grouped_perc = ((sum(list(df_regions_gd_grouped.values[i+1] >1.05 * df_regions_gd_grouped.values[i] for i in range(0,len(df_regions_gd_grouped.values)-1,2))) / len(df_regions_gd_grouped)*200)[0])
df_regions_edc_grouped_perc = ((sum(list(df_regions_edc_grouped.values[i+1] >1.05 * df_regions_edc_grouped.values[i] for i in range(0,len(df_regions_edc_grouped.values)-1,2))) / len(df_regions_edc_grouped)*200)[0])
df_regions_house_grouped_perc = ((sum(list(df_regions_house_grouped.values[i+1] >1.05 * df_regions_house_grouped.values[i] for i in range(0,len(df_regions_house_grouped.values)-1,2))) / len(df_regions_house_grouped)*200)[0])
df_regions_sport_grouped_perc = ((sum(list(df_regions_sport_grouped.values[i+1] > 1.05 *df_regions_sport_grouped.values[i] for i in range(0,len(df_regions_sport_grouped.values)-1,2))) / len(df_regions_sport_grouped)*200)[0])
df_regions_animals_grouped_perc = ((sum(list(df_regions_animals_grouped.values[i+1] > 1.05 *df_regions_animals_grouped.values[i] for i in range(0,len(df_regions_animals_grouped.values)-1,2))) / len(df_regions_animals_grouped)*200)[0])
df_regions_fastfood_grouped_perc = ((sum(list(df_regions_fastfood_grouped.values[i+1] > 1.05 *df_regions_fastfood_grouped.values[i] for i in range(0,len(df_regions_fastfood_grouped.values)-1,2))) / len(df_regions_fastfood_grouped)*200)[0])
df_regions_flowers_grouped_perc = ((sum(list(df_regions_flowers_grouped.values[i+1] > 1.05 *df_regions_flowers_grouped.values[i] for i in range(0,len(df_regions_flowers_grouped.values)-1,2))) / len(df_moscow_flowers_grouped)*200)[0])
df_regions_carsharing_grouped_perc = 0 # нет данных
df_regions_auto_grouped_perc = 0 # нет данных

# %%
df_moscow_gd_grouped
# Out:
#                                           оборот_жд_билеты
# ключ_клиента активация_кэшбэка_жд_билеты
# 2213         0.0                                   24517.4
#              1.0                                   45418.0
# 1104727      0.0                                   12695.6
#              1.0                                   32779.0
# 1116891      0.0                                       0.0
# ...                                                    ...
# 1002607234   1.0                                       0.0
# 1002997975   0.0                                       0.0
#              1.0                                       0.0
# 1005319581   0.0                                     540.0
#              1.0                                       0.0
#
# [3660 rows x 1 columns]

# %%
print(df_regions_gd_grouped_perc,df_regions_edc_grouped_perc,df_regions_house_grouped_perc,df_regions_sport_grouped_perc, df_regions_animals_grouped_perc,
      df_regions_fastfood_grouped_perc,df_regions_flowers_grouped_perc,df_regions_carsharing_grouped_perc,df_regions_auto_grouped_perc,df_moscow_gd_grouped_perc,df_moscow_edc_grouped_perc,df_moscow_house_grouped_perc,df_moscow_sport_grouped_perc, df_moscow_animals_grouped_perc,
      df_moscow_fastfood_grouped_perc,df_moscow_flowers_grouped_perc,df_moscow_carsharing_grouped_perc,df_moscow_auto_grouped_perc,df_saint_gd_grouped_perc,df_saint_edc_grouped_perc,df_saint_house_grouped_perc,df_saint_sport_grouped_perc, df_saint_animals_grouped_perc,
      df_saint_fastfood_grouped_perc,df_saint_flowers_grouped_perc,df_saint_carsharing_grouped_perc,df_saint_auto_grouped_perc)
# Out:
# 42.84284284284284 46.96048632218845 40.06359300476948 34.74683544303797 46.44607843137255 40.0 35.23809523809524 0 0 45.13661202185793 48.75148632580262 35.05535055350554 28.474320241691842 45.28763769889841 39.823008849557525 41.34920634920635 42.02127659574468 7.926829268292683 45.78005115089514 54.69613259668509 38.35616438356164 32.89902280130293 48.9451476793249 53.84615384615385 0.0011416666666666667 39.53488372093023 0

# %%
pd.DataFrame({'Регионы': [df_regions_gd_grouped_perc,df_regions_edc_grouped_perc,df_regions_house_grouped_perc,df_regions_sport_grouped_perc, df_regions_animals_grouped_perc,
      df_regions_fastfood_grouped_perc,df_regions_flowers_grouped_perc,df_regions_carsharing_grouped_perc,df_regions_auto_grouped_perc],
              'Москва': [df_moscow_gd_grouped_perc,df_moscow_edc_grouped_perc,df_moscow_house_grouped_perc,df_moscow_sport_grouped_perc, df_moscow_animals_grouped_perc,
      df_moscow_fastfood_grouped_perc,df_moscow_flowers_grouped_perc,df_moscow_carsharing_grouped_perc,df_moscow_auto_grouped_perc],
              'Питер': [df_saint_gd_grouped_perc,df_saint_edc_grouped_perc,df_saint_house_grouped_perc,df_saint_sport_grouped_perc, df_saint_animals_grouped_perc,
      df_saint_fastfood_grouped_perc,df_saint_flowers_grouped_perc,df_saint_carsharing_grouped_perc,df_saint_auto_grouped_perc]}).to_excel('regions_artem.xlsx')

# %%
for c in [df_regions_gd_grouped,df_regions_edc_grouped,df_regions_house_grouped,df_regions_sport_grouped, df_regions_animals_grouped,
      df_regions_fastfood_grouped,df_regions_flowers_grouped,df_regions_carsharing_grouped,df_regions_auto_grouped,df_moscow_gd_grouped,df_moscow_edc_grouped,df_moscow_house_grouped,df_moscow_sport_grouped, df_moscow_animals_grouped,
      df_moscow_fastfood_grouped,df_moscow_flowers_grouped,df_moscow_carsharing_grouped,df_moscow_auto_grouped,df_saint_gd_grouped,df_saint_edc_grouped,df_saint_house_grouped,df_saint_sport_grouped, df_saint_animals_grouped,
      df_saint_fastfood_grouped,df_saint_flowers_grouped,df_saint_carsharing_grouped,df_saint_auto_grouped]:
    print(len(c))
# Out:
# 1998
# 1316
# 1258
# 3160
# 1632
# 190
# 2144
# 110
# 76
# 3660
# 1682
# 1084
# 2648
# 1634
# 226
# 2520
# 376
# 328
# 782
# 362
# 292
# 614
# 474
# 26
# 600
# 86
# 54
